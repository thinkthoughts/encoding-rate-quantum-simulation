# %% [markdown]
# # 00 Context

# %% [markdown]
# ## Paper
#
# **arXiv:2606.25011** — *Fast and Parallel High-Rate STAR Architecture for Megaquop Quantum Simulation*.
#
# Working lab-report title: **Encoding Rate Specifies Scalable Quantum Simulation**.
#
# Leading claim: encoding rate is not a trailing implementation detail. It specifies the viable architecture because it couples logical-qubit density, STAR injection amortization, and hardware-native neutral-atom shifts.

# %% [markdown]
# ## Constraint chain
#
# ```text
# translation symmetry
#   -> bicycle chain code choice
#   -> native Clifford operations
#   -> disjoint logical representatives
#   -> parallel STAR injection across k logical qubits
#   -> lower physical-qubit overhead
# ```

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

FIG_DIR = Path('../figures')
FIG_DIR.mkdir(exist_ok=True)

# %%
claims = pd.DataFrame([
    {'constraint': 'encoding_rate', 'role': 'leading specification'},
    {'constraint': 'translation_symmetry', 'role': 'code + hardware compiler'},
    {'constraint': 'parallel_STAR_injection', 'role': 'amortizes resource preparation'},
    {'constraint': 'neutral_atom_AOD_shifts', 'role': 'hardware-native low-depth operations'},
])
claims
